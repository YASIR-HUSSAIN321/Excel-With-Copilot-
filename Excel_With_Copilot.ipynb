# %% [markdown]
# #Excel With Copilot

# %% [markdown]
# # Q1. Use Copilot to identify and summarize missing values in the dataset.
# .df.isnull()->shows true where values are missing .
# .df.isnull()>sum()->gives the total missing values in each column.
# Q2. Use Copilot to fill missing values in the Region  and category columns.
# 1.fillna('unkown'->replace missing values with the a placeholder.
# 2.alternatively
# fillna(df['column'].mode ()[0]->  replace missing values with most frequent value, which is the often used in category data
